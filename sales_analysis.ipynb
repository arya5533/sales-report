# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("sales.csv")

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Add Total column (Price × Quantity)
df['Total'] = df['Price'] * df['Quantity']

# Show DataFrame
print("📊 Full Sales Data:")
print(df)

# Total revenue per product
revenue_by_product = df.groupby('Product')['Total'].sum()
print("\n💰 Total Revenue by Product:")
print(revenue_by_product)

# Best-selling product
best_product = revenue_by_product.idxmax()
best_revenue = revenue_by_product.max()
print(f"\n🏆 Best-selling product: {best_product} (${best_revenue})")

# Monthly sales trend
df['Month'] = df['Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['Total'].sum()

# Plot monthly sales
monthly_sales.plot(kind='line', marker='o', title='Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales ($)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 📊 Full Sales Data:
#         Date   Product  Price  Quantity  Total
# 0 2023-01-05    Laptop   1000         2   2000
# 1 2023-01-07     Mouse     20         5    100
# 2 2023-02-10  Keyboard     50         3    150
# 3 2023-02-15    Laptop    950         1    950
# 4 2023-03-05   Monitor    200         2    400
# 5 2023-03-15     Mouse     25         4    100
#
# 💰 Total Revenue by Product:
# Product
# Keyboard     150
# Laptop      2950
# Monitor      400
# Mouse        200
# Name: Total, dtype: int64
#
# 🏆 Best-selling product: Laptop ($2950)
